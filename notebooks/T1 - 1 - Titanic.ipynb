# %%
import pandas as pd
import numpy as np
import os

# %%
data = pd.read_csv('../datasets/titanic/titanic3.csv')

# %%
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
data2 = pd.read_csv(filepath_or_buffer = '../datasets/titanic/titanic3.csv', 
            sep = ',', 
            dtype = {'name':np.str, 'edad': np.int32}, 
            header = 0, 
            na_filter = False
           )
data2.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2
# 1  0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2       2      1      2  113781  151.5500  C22 C26        S
# 3      30      1      2  113781  151.5500  C22 C26        S       135
# 4      25      1      2  113781  151.5500  C22 C26        S
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# ...

# %%
mainpath = r'C:\Users\u632242\OneDrive - Telecom Argentina SA\Documents\GitHub\python-ml-course' # r se usa para evitar cambiar las barras 
datapath = r'datasets\titanic\titanic3.csv'
fullpath = mainpath + '/' + datapath
print(fullpath)

fullpath = os.path.join(mainpath, datapath)
print(fullpath)
# Out:
# C:\Users\u632242\OneDrive - Telecom Argentina SA\Documents\GitHub\python-ml-course/datasets\titanic\titanic3.csv
# C:\Users\u632242\OneDrive - Telecom Argentina SA\Documents\GitHub\python-ml-course\datasets\titanic\titanic3.csv

# %%
data3 = pd.read_csv(fullpath)
data3.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# ## Carga de datos usando open()
#
# Cuando se usa PANDAS el dataset se lee entero y se carga a memoria. Para datasets grandes se puede usar la funcion open. Muy engorroso.
